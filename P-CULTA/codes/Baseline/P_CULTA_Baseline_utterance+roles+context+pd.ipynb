# %% [markdown]
# <!-- # P-CULTA Baseline Evaluation — v2
# ## Zero-Shot | 4 Models | CAS · FTV (independent) · Bias

# %% [markdown]
# <!-- # P-CULTA Baseline Evaluation — v2
# ## Zero-Shot | 4 Models | CAS · FTV (independent) · Bias
#
# **Fixes applied in this version:**
# - Prompt now includes User Role + Model Role (so models know their social position)
# - FTV is independently human-judged — 2 dedicated FTV dimensions added to annotation sheet
# - CAS uses weighted dimensions (Indirectness + Facesaving weighted higher — culturally justified)
# - Preference validation cell added for CAS metric validation
# - Gold responses annotated by judges — not hardcoded
#
# **Models:**
# | Model | Type |
# |-------|------|
# | GPT-4o-mini | Closed LLM — commercial baseline |
# | Qwen2.5-7B-Instruct | Open LLM — multilingual baseline |
# | LLaMA-3.1-8B-Instruct | Open LLM — instruction-following baseline |
# | Qalb-1.0-8B-Instruct | Urdu-native LLM — regional baseline | -->

# %% [markdown]
# ## 0. Install & Import

# %%
import sys

# !{sys.executable} -m pip install -U \
transformers \
accelerate \
bitsandbytes \
sentencepiece \
huggingface_hub

# %%
# !pip install openai transformers accelerate bitsandbytes pandas scipy scikit-learn matplotlib seaborn tqdm -q
# !pip install -q openai
import os, time, warnings, json
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
from tqdm.notebook import tqdm
from scipy import stats
from sklearn.metrics import cohen_kappa_score
from collections import Counter

warnings.filterwarnings('ignore')

plt.rcParams.update({
    'font.family': 'DejaVu Serif', 'font.size': 11,
    'axes.titlesize': 13, 'axes.labelsize': 11,
    'figure.dpi': 120, 'savefig.dpi': 300, 'savefig.bbox': 'tight',
    'axes.spines.top': False, 'axes.spines.right': False,
    'axes.grid': True, 'grid.alpha': 0.3, 'grid.linestyle': '--'
})

COLORS = {
    'GPT-4o-mini':                '#2166AC',
    'Qwen2.5-7B-Instruct':        '#1B7837',
    'Meta-Llama-3.1-8B-Instruct': '#D6604D',
    'Qalb-1.0-8B-Instruct':       '#7B2D8B',
}

print("✓ Ready")
# Out:
# ✓ Ready

# %% [markdown]
# ## 1. Load Dataset

# %%
df = pd.read_csv(r"P_CULTA_V2.csv")

for col in ['Topic','Power Distance','Register','Sensitivity',
            'User Role','Model Role']:
    df[col] = df[col].str.strip()
df['Sensitivity'] = df['Sensitivity'].str.capitalize()
df = df.reset_index(drop=True)
df.insert(0, 'ID', range(1, len(df)+1))

print(f"Rows: {len(df)}  |  Topics: {df['Topic'].nunique()}")
print(f"Power Distance: {dict(Counter(df['Power Distance']))}")
print(f"Sensitivity:    {dict(Counter(df['Sensitivity']))}")
print(f"Register:       {dict(Counter(df['Register']))}")
df.head(3)
# Out:
# Rows: 255  |  Topics: 17
# Power Distance: {'Medium': 70, 'Low': 73, 'High': 112}
# Sensitivity:    {'Positive': 96, 'Negative': 74, 'Neutral': 85}
# Register:       {'Formal': 164, 'Informal': 91}
#    ID Language            Topic User Role Model Role Power Distance  Register  \
# 0   1     Urdu  Refusing Offers    میزبان      مہمان         Medium    Formal
# 1   2     Urdu  Refusing Offers      دوست       دوست            Low  Informal
# 2   3     Urdu  Refusing Offers       ساس        بہو           High    Formal
#
#                 Pragmatic Genre Sensitivity                   User Utterance  \
# 0  Gratitude + indirect refusal    Positive  اور سالن لے لیجیے، ابھی گرم ہے۔
# 1                Polite refusal    Negative               اور چائے بنوا دوں؟
# 2           Deferential refusal    Positive            بیٹا، اور روٹی لے لو۔
#
#                                              Context  \
# 0  آپ ایک دعوت میں مہمان ہیں۔ کھانے کے دوران میزب...
# 1  آپ اپنے دوست کے گھر ملاقات کے لیے گئے ہیں۔ گفت...
# 2  آپ گھر میں کھانے کی میز پر موجود ہیں۔ کھانے کے...
#
#                                        Gold Response
# 0  آپ کی بڑی مہربانی، واقعی بہت مزیدار تھا، مگر ا...
# 1  نہیں یار، تم نے پہلے ہی بہت خاطر داری کر لی ہے...
# 2  جی امی جان، بہت شکریہ، مگر واقعی اب مزید گنجائ...

# %% [markdown]
# ## 2. Prompt Builder
#
# **What goes in the prompt:**
# - `User Role` + `Model Role` — so the model knows its social position and can calibrate register
# - `Context` — scene setting
# - `User Utterance` — what was said
# - `Power Distance` — Hierarchy level
#
# **What does NOT go in the prompt (true zero-shot baseline):**
# - No cultural instruction
# - No Pakistan mention
# - No examples
# - No chain-of-thought
# - No power distance label
# - No sensitivity label
#
# **Why add roles but nothing else?**
# Without roles, a model cannot possibly know whether to use آپ or تم, or whether deference markers are needed.
# Roles are factual (who is speaking to whom), not cultural guidance. The bias we are measuring
# comes from the model's inability to produce culturally appropriate responses even when it knows
# the social relationship — not from ignorance of who is speaking.

# %%
def build_baseline_prompt(row: pd.Series) -> tuple[str, str]:
    """
    system : role-play instruction only — no culture, no Pakistan, no examples
    user   : speaker role + listener role + power distance + context + utterance
             formatted as a screenplay so the model knows exactly
             what to say next and nothing more

    Gold response is NEVER shown.
    """
    system = (
        "Generate a natural Urdu response. "
        "Output only the response utterance. "
        "Do not explain. "
        "Do not narrate. "
        "Do not add extra context. "
        "Do not ask unnecessary follow-up questions."
    )

    user = (
        f"آپ کا کردار: {row['Model Role']}\n"
        f"مخاطب: {row['User Role']}\n"
        f"Power Distance: {row['Power Distance']}\n\n"
        f"{row['Context']}\n\n"
        f"{row['User Role']}: \"{row['User Utterance']}\"\n\n"
        f"{row['Model Role']}:"
    )

    return system, user


# ── Verify — NO gold response printed ────────────────────────────────
for i in [0, 80, 130]:
    r = df.iloc[i]
    sys_msg, usr_msg = build_baseline_prompt(r)

    print(
        f"Row {i} | {r['Topic']} | "
        f"{r['User Role']} → {r['Model Role']} | "
        f"{r['Power Distance']} PD"
    )
    print(f"SYSTEM: {sys_msg}")
    print(f"USER:\n{usr_msg}")
    print("─" * 60)
# Out:
# Row 0 | Refusing Offers | میزبان → مہمان | Medium PD
# SYSTEM: Generate a natural Urdu response. Output only the response utterance. Do not explain. Do not narrate. Do not add extra context. Do not ask unnecessary follow-up questions.
# USER:
# آپ کا کردار: مہمان
# مخاطب: میزبان
# Power Distance: Medium
#
# آپ ایک دعوت میں مہمان ہیں۔ کھانے کے دوران میزبان آپ کو مزید سالن پیش کرتا ہے۔
#
# میزبان: "اور سالن لے لیجیے، ابھی گرم ہے۔"
#
# مہمان:
# ────────────────────────────────────────────────────────────
# Row 80 | Paying for a Meal | بڑی بہن → بھائی | Medium PD
# SYSTEM: Generate a natural Urdu response. Output only the response utterance. Do not explain. Do not narrate. Do not add extra context. Do not ask unnecessary follow-up questions.
# USER:
# آپ کا کردار: بھائی
# مخاطب: بڑی بہن
# Power Distance: Medium
#
# آپ اپنی بڑی بہن کے ساتھ کھانا کھانے کے بعد بل ادا کرنے لگتے ہیں۔ وہ محبت سے ادائیگی اپنے ذمے لینے کی پیشکش کرتی ہیں۔
#
# بڑی بہن: "میں بل دے دیتی ہوں۔"
#
# بھائی:
# ────────────────────────────────────────────────────────────
# Row 130 | Handling Criticism & Disagreements | والد → بیٹا | High PD
# SYSTEM: Generate a natural Urdu response. Output only the response utterance. Do not explain. Do not narrate. Do not add extra context. Do not ask unnecessary follow-up questions.
# USER:
# آپ کا کردار: بیٹا
# مخاطب: والد
# Power Distance: High
#
# آپ کے والد کسی ایسے کام پر ناراضی کا اظہار کر رہے ہیں جس سے انہوں نے پہلے منع کیا تھا۔
#
# والد: "میں نے منع کیا تھا، پھر بھی تم نے یہ کام کیا۔"
#
# بیٹا:
# ────────────────────────────────────────────────────────────

# %% [markdown]
# ## 3. Response Generation

# %% [markdown]
# ### 3.1 GPT-4o-mini

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "")
from openai import OpenAI, RateLimitError

def generate_gpt(df: pd.DataFrame, api_key: str,
                 save_path: str = "responses_gpt_role+pd.csv") -> pd.DataFrame:

    client    = OpenAI(api_key=api_key)
    responses = []

    for i, row in tqdm(df.iterrows(), total=len(df), desc="GPT-4o-mini"):
        system, user = build_baseline_prompt(row)
        retries, text = 0, "ERROR"

        while retries < 5:
            try:
                resp = client.chat.completions.create(
                    model="gpt-4o-mini",
                    temperature=0.3,
                    max_tokens=40,
                    messages=[
                        {"role": "system", "content": system},
                        {"role": "user",   "content": user},
                    ]
                )
                text = resp.choices[0].message.content.strip()
                break
            except RateLimitError:
                wait = 2 ** retries
                print(f"  Rate limit — waiting {wait}s")
                time.sleep(wait)
                retries += 1
            except Exception as e:
                print(f"  Error row {i}: {e}")
                break

        responses.append(text)

        if i % 25 == 0 and i > 0:
            tmp = df.copy()
            tmp['GPT_Response'] = responses + [''] * (len(df) - len(responses))
            tmp.to_csv(save_path.replace('.csv','_backup.csv'),
                       index=False, encoding='utf-8-sig')
        time.sleep(1.2)

    out = df.copy()
    out['GPT_Response'] = responses
    out.to_csv(save_path, index=False, encoding='utf-8-sig')
    print(f"Saved → {save_path}")
    return out
df_gpt = generate_gpt(df, OPENAI_API_KEY)
# df_gpt = pd.read_csv('responses_gpt_role+pd.csv')

# %% [markdown]
# ### 3.2 HuggingFace Models (Qwen · LLaMA · Qalb)

# %%
def generate_hf(df: pd.DataFrame, model_id: str,
                save_path: str, response_col: str) -> pd.DataFrame:
    """
    Works for: Qwen2.5-7B-Instruct, LLaMA-3.1-8B-Instruct, Qalb-1.0-8B-Instruct
    Needs: GPU ≥ 16GB VRAM  (or Google Colab A100)
    """
    import torch
    from transformers import (AutoTokenizer, AutoModelForCausalLM,
                               BitsAndBytesConfig)

    model_name = model_id.split('/')[-1]
    print(f"Loading {model_name}...")

    bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
    )
    model = AutoModelForCausalLM.from_pretrained(
        model_id, quantization_config=bnb,
        device_map="auto", trust_remote_code=True)
    tokenizer = AutoTokenizer.from_pretrained(
        model_id, trust_remote_code=True)

    responses = []

    for i, row in tqdm(df.iterrows(), total=len(df), desc=model_name):
        system, user = build_baseline_prompt(row)
        messages = [{"role":"system","content":system},
                    {"role":"user",  "content":user}]

        try:
            text_in = tokenizer.apply_chat_template(
                messages, tokenize=False, add_generation_prompt=True)
        except Exception:
            text_in = f"{system}\n{user}\n"

        inputs = tokenizer(text_in, return_tensors="pt").to(model.device)

        with torch.no_grad():
            out = model.generate(
                **inputs,
                max_new_tokens=40, temperature=0.3,
                do_sample=True, pad_token_id=tokenizer.eos_token_id,
                repetition_penalty=1.1)

        new_tok  = out[0][inputs['input_ids'].shape[1]:]
        response = tokenizer.decode(new_tok, skip_special_tokens=True).strip()
        responses.append(response)

        if i % 25 == 0 and i > 0:
            tmp = df.copy()
            tmp[response_col] = responses + [''] * (len(df)-len(responses))
            tmp.to_csv(save_path.replace('.csv','_backup.csv'),
                       index=False, encoding='utf-8-sig')

    out = df.copy()
    out[response_col] = responses
    out.to_csv(save_path, index=False, encoding='utf-8-sig')
    print(f"Saved → {save_path}")
    return out

df_qwen  = generate_hf(df, "Qwen/Qwen2.5-7B-Instruct",
                        "responses_qwen_role+pd.csv",  "Qwen_Response")
df_llama = generate_hf(df, "meta-llama/Meta-Llama-3.1-8B-Instruct",
                         "responses_llama_role+pd.csv", "LLaMA_Response")
df_qalb  = generate_hf(df, "enstazao/Qalb-1.0-8B-Instruct",
                         "responses_qalb_role+pd.csv",  "Qalb_Response")

# %% [markdown]
# ### 3.3 Merge All Responses

# %%
df_gpt   = pd.read_csv(r'responses_gpt_role+pd.csv')
df_qwen  = pd.read_csv(r'responses_qwen_role+pd.csv')
df_llama = pd.read_csv(r'responses_llama_role+pd.csv')
df_qalb  = pd.read_csv(r'responses_qalb_role+pd.csv')

merged = df_gpt.copy()
for other, col in [(df_qwen,  'Qwen_Response'),
                   (df_llama, 'LLaMA_Response'),
                   (df_qalb,  'Qalb_Response')]:
    merged = merged.merge(other[['ID', col]], on='ID', how='left')

RESPONSE_COLS = {
    'GPT-4o-mini':                'GPT_Response',
    'Qwen2.5-7B-Instruct':        'Qwen_Response',
    'Meta-Llama-3.1-8B-Instruct': 'LLaMA_Response',
    'Qalb-1.0-8B-Instruct':       'Qalb_Response',
}

print(f"Merged: {len(merged)} rows")
for model, col in RESPONSE_COLS.items():
    n = merged[col].notna().sum()
    print(f"  {model:38s} {n} responses")

merged.head(3)
# Out:
# Merged: 255 rows
#   GPT-4o-mini                            255 responses
#   Qwen2.5-7B-Instruct                    255 responses
#   Meta-Llama-3.1-8B-Instruct             255 responses
#   Qalb-1.0-8B-Instruct                   255 responses
#    ID Language            Topic User Role Model Role Power Distance  Register  \
# 0   1     Urdu  Refusing Offers    میزبان      مہمان         Medium    Formal
# 1   2     Urdu  Refusing Offers      دوست       دوست            Low  Informal
# 2   3     Urdu  Refusing Offers       ساس        بہو           High    Formal
#
#                 Pragmatic Genre Sensitivity                   User Utterance  \
# 0  Gratitude + indirect refusal    Positive  اور سالن لے لیجیے، ابھی گرم ہے۔
# 1                Polite refusal    Negative               اور چائے بنوا دوں؟
# 2           Deferential refusal    Positive            بیٹا، اور روٹی لے لو۔
#
#                                              Context  \
# 0  آپ ایک دعوت میں مہمان ہیں۔ کھانے کے دوران میزب...
# 1  آپ اپنے دوست کے گھر ملاقات کے لیے گئے ہیں۔ گفت...
# 2  آپ گھر میں کھانے کی میز پر موجود ہیں۔ کھانے کے...
#
#                                        Gold Response  \
# 0  آپ کی بڑی مہربانی، واقعی بہت مزیدار تھا، مگر ا...
# 1  نہیں یار، تم نے پہلے ہی بہت خاطر داری کر لی ہے...
# 2  جی امی جان، بہت شکریہ، مگر واقعی اب مزید گنجائ...
#
#                                         GPT_Response  \
# 0              "بہت شکریہ، یہ واقعی بہت مہربانی ہے۔"
# 1  "ہاں، کیوں نہیں! ایک اور کپ چائے تو بنوا دو، ب...
# 2  "جی امی، شکریہ۔ آپ کی محبت کا بہت خیال رکھتی ہ...
#
#                                        Qwen_Response  \
# 0                    بس کچھ لے لیں، مزہ بیٹا آئے گا۔
# 1                  میری طرف سے بنا لیں گے، تیار ہوں۔
# 2  میں نے قسمت کچھ لی ہے، لیکن تیری پانسی کچھ بیش...
#
#                                       LLaMA_Response  \
# 0  "شکر ہوگا، مجھے بہت پسند آئیں گے۔ کیا یہ پاپاد...
# 1  "جی، بہت ہی خوشی ہوگی، آج تو مجھے چائے کی ضرور...
# 2  "جی ساس جی، شکر ہوگا۔ لیکن مجھے پتہ نہیں کہ اب...
#
#                                        Qalb_Response
# 0  "شکریہ، یہ بہت مزیدار ہے." (Answer)\n'''\nAnsw...
# 1  "جی ہاں، مجھے مزید چائے کی ضرورت ہے۔"\n'''\n##...
# 2  "سسرالی، میری ماں نے مجھے روٹی دینے کے لیے کہا...

# %% [markdown]
# ## 4. Annotation Sheets
#
# **6 columns to fill per response (0–4 scale):**
#
# **CAS dimensions** (higher = better cultural alignment):
# - `Relational_Alignment` — appropriateness of the interpersonal relationship, including suitable respect, familiarity, warmth, acknowledgment, and deference for the specified roles and power distance.
# - `Indirectness` — polite indirect phrasing used
# - `Facesaving` — interlocutor's izzat protected
# - `Cultural_Appropriateness` — overall fit to Pakistani norms
#
# **FTV dimensions — independently judged** (higher = more face-threatening):
# - `Directness_Threat` — how bluntly does response impose or refuse?
# - `Hierarchy_Violation` — wrong register for the role relationship?
#
# **Scale:**
# | Score | Meaning |
# |-------|---------|
# | 0 | Absent / completely wrong |
# | 1 | Weak presence/ major shortcomings |
# | 2 | Partial / acceptable |
# | 3 | Strong realization/ minor shortcomings |
# | 4 | Full / culturally appropriate |
#
# **Also annotate Gold Responses** using same 6 dimensions.
# These become the true gold scores — not hardcoded values.

# %%
def create_annotation_sheets(merged: pd.DataFrame,
                              response_cols: dict,
                              n_judges: int = 2,
                              out_dir: str = "annotation_pd"):

    Path(out_dir).mkdir(exist_ok=True)
    rng    = np.random.default_rng(42)
    models = list(response_cols.keys())
    labels = list('ABCD')[:len(models)]

    # Annotation dimensions
    CAS_DIMS = ['Relational_Alignment','Indirectness','Facesaving',
                'Cultural_Appropriateness']
    FTV_DIMS = ['Directness_Threat','Hierarchy_Violation']
    ALL_DIMS = CAS_DIMS + FTV_DIMS

    all_mappings = []

    for judge_idx in range(1, n_judges + 1):
        rows = []
        mappings = []

        for _, row in merged.iterrows():
            order = rng.permutation(models).tolist()

            sheet_row = {
                'ID':             row['ID'],
                'Power_Distance': row['Power Distance'],
                'User_Role':      row['User Role'],
                'Model_Role':     row['Model Role'],
                'Context':        row['Context'],
                'User_Utterance': row['User Utterance'],
                'Gold_Response':  row['Gold Response'],
            }

            # Gold annotation columns (judges score the gold response too)
            for dim in ALL_DIMS:
                sheet_row[f'Gold_{dim}'] = ''

            # Blind model responses + blank score columns
            for label, model in zip(labels, order):
                col = response_cols[model]
                sheet_row[f'Response_{label}'] = row.get(col, '')
                for dim in ALL_DIMS:
                    sheet_row[f'{label}_{dim}'] = ''

            rows.append(sheet_row)

            m = {'ID': row['ID'], 'Judge': f'Judge{judge_idx}'}
            for label, model in zip(labels, order):
                m[label] = model
            mappings.append(m)

        sheet_path = f"{out_dir}/judge{judge_idx}_baseline_pd.csv"
        pd.DataFrame(rows).to_csv(sheet_path, index=False, encoding='utf-8-sig')
        print(f"  Saved: {sheet_path}")
        all_mappings.extend(mappings)

    mapping_path = f"{out_dir}/mapping_key.csv"
    pd.DataFrame(all_mappings).to_csv(mapping_path, index=False)
    print(f"  Saved: {mapping_path}  ← DO NOT share with judges")
    print(f"\nEach judge scores {len(merged)} rows × {len(models)} responses × {len(ALL_DIMS)} dims")
    print(f"  CAS dims: {CAS_DIMS}")
    print(f"  FTV dims (independent): {FTV_DIMS}")


create_annotation_sheets(merged, RESPONSE_COLS)
# Out:
#   Saved: annotation_pd/judge1_baseline_pd.csv
#   Saved: annotation_pd/judge2_baseline_pd.csv
#   Saved: annotation_pd/mapping_key.csv  ← DO NOT share with judges
#
# Each judge scores 255 rows × 4 responses × 6 dims
#   CAS dims: ['Relational_Alignment', 'Indirectness', 'Facesaving', 'Cultural_Appropriateness']
#   FTV dims (independent): ['Directness_Threat', 'Hierarchy_Violation']

# %% [markdown]
# ## 5. Metric Computation
#
# ### Formulas
#
# **CAS** — weighted average of 4 CAS dimensions, compared to gold:
# ```
#  CAS  = 1 - mean( |model_i - gold_i| / S_MAX )   equal weights
#
#
# ```
#
# **FTV** — independently human-judged, weighted average of 2 FTV dimensions:
# ```
#  FTV  = mean( model_j / S_MAX )
#
#
# FTV is now a genuinely independent metric — judges score it separately
# from CAS dimensions. It no longer derives from the Indirectness score.
# ```
#
# **Bias**:
# ```
# Bias = 1 - CAS
# ```

# %%
# ── Dimension names (exact as in annotation files) ────────────────────────
# NOTE: "Relational _Alignment" has a space before underscore in the CSV files
CAS_DIMS = [
    'Relational_Alignment',
    'Indirectness',
    'Facesaving',
    'Cultural_Appropriateness',
]
FTV_DIMS = [
    'Directness_Threat',
    'Hierarchy_Violation',
]
ALL_DIMS = CAS_DIMS + FTV_DIMS
S_MAX    = 4.0     # 0–4 scale
LABELS   = ['A', 'B', 'C', 'D']


def load_sheet(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    for c in df.columns:
        if any(dim in c for dim in ALL_DIMS):
            df[c] = pd.to_numeric(df[c], errors='coerce')
    return df


def load_mapping(path: str) -> pd.DataFrame:
    """Load mapping key — supports .csv or .xls"""
    if path.endswith('.xls') or path.endswith('.xlsx'):
        try:
            return pd.read_excel(path, engine='openpyxl')
        except Exception:
            return pd.read_csv(path, encoding='utf-8-sig')
    return pd.read_csv(path)


def compute_all_metrics(j1: pd.DataFrame,
                        j2: pd.DataFrame,
                        mapping: pd.DataFrame) -> pd.DataFrame:
    """
    Average two judges → compute CAS, FTV, Bias per (item, model).

    CAS  = 1 - mean( |model_i - gold_i| / S_MAX )   equal weights
    FTV  = mean( model_j / S_MAX )                   equal weights
    Bias = 1 - CAS
    """
    # Average the two judges for all score columns
    averaged = j1.copy()
    for label in LABELS + ['Gold']:
        for dim in ALL_DIMS:
            col = f'{label}_{dim}'
            if col in j1.columns and col in j2.columns:
                averaged[col] = (j1[col] + j2[col]) / 2.0

    map_j1 = mapping[mapping['Judge'] == 'Judge1']
    rows   = []

    for _, arow in averaged.iterrows():
        item_id = arow['ID']
        mrow    = map_j1[map_j1['ID'] == item_id]
        if len(mrow) == 0:
            continue
        mrow = mrow.iloc[0]

        # Gold scores from judge annotation (not hardcoded)
        gold = {dim: arow.get(f'Gold_{dim}', np.nan) for dim in ALL_DIMS}

        for label in LABELS:
            model = mrow.get(label, f'Unknown_{label}')
            ms    = {dim: arow.get(f'{label}_{dim}', np.nan) for dim in ALL_DIMS}

            # ── CAS: equal weights, deviation from gold ───────────────
            diffs = [
                abs(ms[d] - gold[d]) / S_MAX
                for d in CAS_DIMS
                if pd.notna(ms[d]) and pd.notna(gold[d])
            ]
            cas = (1.0 - np.mean(diffs)) if diffs else np.nan

            # ── FTV: equal weights, mean of FTV dimensions ────────────
            ftv_vals = [
                ms[d] / S_MAX
                for d in FTV_DIMS
                if pd.notna(ms[d])
            ]
            ftv = np.mean(ftv_vals) if ftv_vals else np.nan

            # ── Bias ─────────────────────────────────────────────────
            bias = 1.0 - cas if pd.notna(cas) else np.nan

            rows.append({
                'ID':             item_id,
                'Model':          model,
                'Topic':          arow.get('Topic', ''),
                'Power_Distance': arow.get('Power_Distance', ''),
                'Register':       arow.get('Register', ''),
                'Sensitivity':    arow.get('Sensitivity', ''),
                'CAS':            round(float(cas),  4) if pd.notna(cas)  else np.nan,
                'FTV':            round(float(ftv),  4) if pd.notna(ftv)  else np.nan,
                'Bias':           round(float(bias), 4) if pd.notna(bias) else np.nan,
                **{f'model_{d}': ms[d]   for d in ALL_DIMS},
                **{f'gold_{d}':  gold[d] for d in ALL_DIMS},
            })

    return pd.DataFrame(rows)


# ── Load completed judge sheets and mapping ───────────────────────────────
j1      = load_sheet(r'annotation_pd/judge1_baseline_pd_annotated.csv')
j2      = load_sheet(r'annotation_pd/judge2_baseline_pd_annotated.csv')
mapping = load_mapping(r'annotation_pd/mapping_key.csv')   # or mapping_key.csv

results = compute_all_metrics(j1, j2, mapping)
results.to_csv('baseline_pdresults.csv', index=False, encoding='utf-8-sig')

print(f"Results: {len(results)} rows ({results['Model'].nunique()} models × {results['ID'].nunique()} items)")
print()
print(results.groupby('Model')[['CAS','FTV','Bias']].mean().round(4).to_string())
# Out:
# Results: 1020 rows (4 models × 255 items)
#
#                                CAS     FTV    Bias
# Model
# GPT-4o-mini                 0.7511  0.0319  0.2489
# Meta-Llama-3.1-8B-Instruct  0.3004  0.1713  0.6996
# Qalb-1.0-8B-Instruct        0.3156  0.1998  0.6844
# Qwen2.5-7B-Instruct         0.0915  0.3637  0.9085

# %% [markdown]
# ## 6. Inter-Annotator Agreement (Cohen's κ)

# %%
def compute_kappas(j1: pd.DataFrame, j2: pd.DataFrame) -> pd.DataFrame:
    rows = []

    for dim in ALL_DIMS:
        r1_all, r2_all = [], []
        for label in LABELS + ['Gold']:
            col = f'{label}_{dim}'
            if col in j1.columns and col in j2.columns:
                mask = j1[col].notna() & j2[col].notna()
                r1_all.extend(j1.loc[mask, col].astype(int).tolist())
                r2_all.extend(j2.loc[mask, col].astype(int).tolist())

        if len(r1_all) < 5:
            continue

        kappa    = cohen_kappa_score(r1_all, r2_all, weights='quadratic')
        strength = ('Almost Perfect' if kappa > 0.80 else
                    'Substantial'    if kappa > 0.61 else
                    'Moderate'       if kappa > 0.41 else 'Fair')
        metric   = 'CAS' if dim in CAS_DIMS else 'FTV'

        rows.append({
            'Dimension': dim, 'Metric': metric,
            'κ': round(kappa, 4), 'Strength': strength, 'N': len(r1_all)
        })

    return pd.DataFrame(rows)


kappas = compute_kappas(j1, j2)
print("=== Inter-Annotator Agreement (quadratic weighted κ) ===")
print(kappas.to_string(index=False))

min_k = kappas['κ'].min()
print()
if min_k < 0.61:
    print(f"⚠  Minimum κ = {min_k:.4f} — calibration session recommended")
else:
    print(f"✓  All κ ≥ 0.61 — acceptable for publication")

kappas.to_csv('baseline_pdkappas.csv', index=False)
# Out:
# === Inter-Annotator Agreement (quadratic weighted κ) ===
#                Dimension Metric      κ       Strength    N
#     Relational_Alignment    CAS 0.9931 Almost Perfect 1275
#             Indirectness    CAS 0.9909 Almost Perfect 1275
#               Facesaving    CAS 0.9970 Almost Perfect 1275
# Cultural_Appropriateness    CAS 0.9997 Almost Perfect 1275
#        Directness_Threat    FTV 0.9875 Almost Perfect 1275
#      Hierarchy_Violation    FTV 0.9734 Almost Perfect 1275
#
# ✓  All κ ≥ 0.61 — acceptable for publication

# %% [markdown]
# ## 7. Summary Statistics

# %%
summary = (
    results.groupby('Model')[['CAS','FTV','Bias']]
    .agg(
        CAS_mean  =('CAS', 'mean'),  CAS_std  =('CAS', 'std'),
        FTV_mean  =('FTV', 'mean'),  FTV_std  =('FTV', 'std'),
        Bias_mean =('Bias','mean'),  Bias_std =('Bias','std'),
    )
    .round(4).reset_index()
)

summary['CAS']  = summary.apply(lambda r: f"{r.CAS_mean:.3f} ± {r.CAS_std:.3f}",  axis=1)
summary['FTV']  = summary.apply(lambda r: f"{r.FTV_mean:.3f} ± {r.FTV_std:.3f}",  axis=1)
summary['Bias'] = summary.apply(lambda r: f"{r.Bias_mean:.3f} ± {r.Bias_std:.3f}",axis=1)

print("=== BASELINE_pd RESULTS TABLE ===")
print(summary[['Model','CAS','FTV','Bias']].to_string(index=False))
summary.to_csv('baseline_pd_summary.csv', index=False)
# Out:
# === BASELINE_pd RESULTS TABLE ===
#                      Model           CAS           FTV          Bias
#                GPT-4o-mini 0.751 ± 0.235 0.032 ± 0.088 0.249 ± 0.235
# Meta-Llama-3.1-8B-Instruct 0.300 ± 0.211 0.171 ± 0.177 0.700 ± 0.211
#       Qalb-1.0-8B-Instruct 0.316 ± 0.248 0.200 ± 0.223 0.684 ± 0.248
#        Qwen2.5-7B-Instruct 0.091 ± 0.113 0.364 ± 0.163 0.908 ± 0.113

# %% [markdown]
# ## 8. Figures

# %% [markdown]
# ### Fig 1 — CAS · FTV comparison

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

for ax, metric, title in zip(
    axes,
    ['CAS', 'FTV'],
    ['Cultural Alignment Score  ↑  higher is better',
     'Face-Threatening Value  ↓  lower is safer']
):
    means = (results.groupby('Model')[metric].mean()
             .sort_values(ascending=(metric=='FTV')))
    colors = [COLORS.get(m,'#888') for m in means.index]

    bars = ax.bar(range(len(means)), means.values,
                  color=colors, alpha=0.85, width=0.5)
    for bar, val in zip(bars, means.values):
        ax.text(bar.get_x()+bar.get_width()/2,
                bar.get_height()+0.012,
                f'{val:.3f}', ha='center', fontsize=10)

    ax.set_xticks(range(len(means)))
    ax.set_xticklabels(
        [m.replace('-Instruct','') for m in means.index],
        rotation=12, fontsize=10)
    ax.set_ylim(0, 1.1)
    ax.set_ylabel(metric, fontsize=11)
    ax.set_title(title, fontsize=12, pad=8)

plt.suptitle('P-CULTA Baseline_pd: Zero-Shot Results_pd', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('fig1_cas_ftv_pd.pdf')
plt.savefig('fig1_cas_ftv_pd.png', dpi=300)
plt.show()

# %% [markdown]
# ### 9. Bias evidence

# %%
bias_evidence = []

for model in results['Model'].unique():
    top = results[results['Model']==model].nlargest(3,'FTV')
    for _, r in top.iterrows():
        item = merged[merged['ID'] == r['ID']].iloc[0]
        col  = RESPONSE_COLS.get(model, '')
        resp = item.get(col,'') if col else ''
        bias_evidence.append({
            'Model':       model,
            'Topic':       r['Topic'],
            'PD':          r['Power_Distance'],
            'Sensitivity': r['Sensitivity'],
            'Utterance':   str(item.get('User Utterance','')),
            'Gold':        str(item.get('Gold Response','')),
            'Response':    str(resp)[:100],
            'CAS':         r['CAS'],
            'FTV':         r['FTV'],
            'Bias':        r['Bias'],
        })

bias_df = (pd.DataFrame(bias_evidence)
           .sort_values('FTV', ascending=False))
bias_df.to_csv('baseline_bias_evidence_pd.csv',
               index=False, encoding='utf-8-sig')

print("=== TOP FACE-THREATENING RESPONSES (Bias Evidence) ===")
for _, row in bias_df.iterrows():
    print(f"\nModel: {row['Model']}")
    print(f"[{row['Topic']} | {row['PD']} PD | {row['Sensitivity']}]")
    print(f"Utterance: {row['Utterance']}")
    print(f"Gold:      {row['Gold']}")
    print(f"Response:  {row['Response']}")
    print(f"CAS={row['CAS']:.3f}  FTV={row['FTV']:.3f}  Bias={row['Bias']:.3f}")
# Out:
# === TOP FACE-THREATENING RESPONSES (Bias Evidence) ===
#
# Model: Qalb-1.0-8B-Instruct
# [ | Medium PD | ]
# Utterance: اگر کسی چیز کی ضرورت ہو تو بے تکلف بتا دیجیے گا۔
# Gold:      آپ کی مہربانی، فی الحال تو سب ٹھیک ہے، لیکن ضرورت پڑی تو ضرور بتاؤں گا۔
# Response:  "کیا آپ کو مدد کی ضرورت ہے؟"
# '''
# Answer: "اگر کسی چیز کی ضرورت ہو تو بے تکلف بتا دی
# CAS=0.000  FTV=0.750  Bias=1.000
#
# Model: Qalb-1.0-8B-Instruct
# [ | Low PD | ]
# Utterance: میں تمہارے ساتھ ہوں، فکر مت کرو۔
# Gold:      یار، تمہارا ساتھ ہونا ہی حوصلہ دیتا ہے۔
# Response:  "تمہاری مدد کرنے کے لئے میں یہاں ہوں۔"
# '''
# ### 2
# CAS=0.094  FTV=0.750  Bias=0.906
#
# Model: Qalb-1.0-8B-Instruct
# [ | Low PD | ]
# Utterance: یار، کل ایک فنکشن ہے، تم بھی ساتھ چلو۔
# Gold:      ہاں یار، اگر کوئی ضروری کام نہ نکلا تو میں ضرور چلوں گا۔
# Response:  "کل کو ایک فنکشن ہے، تم بھی آؤ گے؟"
# '''
# Answer: "جی ہاں، مجھ�
# CAS=0.000  FTV=0.750  Bias=1.000
#
# Model: Qwen2.5-7B-Instruct
# [ | High PD | ]
# Utterance: چھوڑو، میں کر دیتی ہوں، تم کافی تھک گئے ہو۔
# Gold:      امی، آپ زحمت نہ کریں، میں کر لوں گا، بس تھوڑا سا کام باقی ہے۔
# Response:  میری والدہ، تم نے مجھ سے کتنا آرام دینا چاہا تھا، میں صرف کچھ کام
# CAS=0.031  FTV=0.750  Bias=0.969
#
# Model: Qwen2.5-7B-Instruct
# [ | High PD | ]
# Utterance: ابا جی، اگر آپ مصروف نہ ہوں تو آپ سے ایک بات کرنی تھی۔
# Gold:      جی بیٹا، کہو میں سن رہا ہوں۔
# Response:  ابا جی، میری خواہش یہ ہے کہ آپ مجھ سے پہلے بات کرتے ہوں۔
# CAS=0.000  FTV=0.750  Bias=1.000
#
# Model: GPT-4o-mini
# [ | Medium PD | ]
# Utterance: مجھے خوشی ہے کہ میں وقت پر آپ کی مدد کر سکا۔
# Gold:      آپ کا بہت شکریہ، آپ کی بروقت مدد میرے بہت کام آئی۔
# Response:  "آپ کی مدد کرنا میرے لیے خوشی کی بات ہے۔ ہم سب کو ایک دوسرے کا ساتھ دینا چاہیے۔"
# CAS=0.062  FTV=0.750  Bias=0.938
#
# Model: Meta-Llama-3.1-8B-Instruct
# [ | Low PD | ]
# Utterance: یار، یہ ایک چھوٹی سی چیز تمہارے لیے لایا ہوں، رکھ لو۔
# Gold:      ارے یار! تم خود ملنے آ گئے میرے لیے یہی بہت تھا، اس تکلف کی کیا ضرورت تھی۔
# Response:  "نہیں نہیں، بھلا کر دو، میں نے تو بس تھوڑا سا کچن ل
# CAS=0.031  FTV=0.625  Bias=0.969
#
# Model: Meta-Llama-3.1-8B-Instruct
# [ | Medium PD | ]
# Utterance: آج آپ میرے مہمان ہیں، بل کی فکر نہ کریں۔
# Gold:      سر، آپ کی عنایت ہے، لیکن آپ نے پہلے ہی بہت وقت دیا، مجھے بھی کچھ خدمت کا موقع دیجیے۔
# Response:  استاد صاحب، آپ کو بہت معاف کیا جاتا ہے لیکن مجھے یقین ہے کہ آپ
# CAS=0.000  FTV=0.625  Bias=1.000
#
# Model: Meta-Llama-3.1-8B-Instruct
# [ | High PD | ]
# Utterance: بل مجھے دے دو، میں ادا کر دیتا ہوں۔
# Gold:      ابو، آپ کا خیال اپنی جگہ، لیکن اس بار مجھے موقع دیجیے۔
# Response:  "نہیں نانا، یہ تو میرا پیسہ ہے، تم کو کیا لاجشگت ہ�
# CAS=0.000  FTV=0.625  Bias=1.000
#
# Model: Qwen2.5-7B-Instruct
# [ | High PD | ]
# Utterance: آج رات آپ ہمارے ساتھ کھانا ضرور کھائیے گا۔
# Gold:      بہت شکریہ، آپ کی محبت ہے، ان شاء اللہ ضرور آنے کی کوشش کروں گا۔
# Response:  میں بھی آئے گا، مامو سان।
# CAS=0.031  FTV=0.625  Bias=0.969
#
# Model: GPT-4o-mini
# [ | Medium PD | ]
# Utterance: اور سالن لے لیجیے، ابھی گرم ہے۔
# Gold:      آپ کی بڑی مہربانی، واقعی بہت مزیدار تھا، مگر اب بالکل گنجائش نہیں رہی۔
# Response:  "بہت شکریہ، یہ واقعی بہت مہربانی ہے۔"
# CAS=0.000  FTV=0.500  Bias=1.000
#
# Model: GPT-4o-mini
# [ | Medium PD | ]
# Utterance: اگر آپ چاہیں تو میں بازار سے آپ کے لیے کچھ لے آؤں۔
# Gold:      آپ کی بہت مہربانی، لیکن میں خود انتظام کر لوں گا۔
# Response:  "بہت مہربانی، اگر آپ کچھ پھل لے آئیں تو بہت اچھا ہوگا۔"
# CAS=0.125  FTV=0.375  Bias=0.875
